# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
from datetime import datetime
import json 
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 603

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | kavieng
# Processing Record 3 of Set 1 | saint cloud
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | severo-kurilsk
# Processing Record 6 of Set 1 | yatou
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | puerto del rosario
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | dekar
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | milledgeville
# Processing Record 18 of Set 1 | alcanena
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | severnyy
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | dores do indaia
# Processing Record 28 of Set 1 | grindavik
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | fairbanks
# Processing Record 31 of Set 1 | salalah
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | srednekolymsk
# Processing Record 34 of Set 1 | kungurtug
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 1 | prince rupert
# Processing Record 37 of Set 1 | kupang
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | surt
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | souillac
# Processing Record 42 of Set 1 | tecoanapa
# Processing Record 43 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | bambous virieux
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | kahului
# Processing Record 48 of Set 1 | les trois-ilets
# Processing Record 49 of Set 1 | carrollton
# Processing Record 50 of Set 1 | beringovskiy
# Processing Record 1 of Set 2 | whyalla
# Processing Record 2 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 2 | weyburn
# Processing Record 4 of Set 2 | sao filipe
# Processing Record 5 of Set 2 | herat
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | sale
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | nishihara
# Processing Record 12 of Set 2 | rochegda
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | rawson
# Processing Record 15 of Set 2 | verkhoyansk
# Processing Record 16 of Set 2 | norman wells
# Processing Record 17 of Set 2 | ferme-neuve
# Processing Record 18 of Set 2 | isangel
# Processing Record 19 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 2 | saint george
# Processing Record 21 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 2 | porto torres
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | mumford
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 2 | thinadhoo
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | sao felix do xingu
# Processing Record 34 of Set 2 | celestun
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | kikwit
# Processing Record 37 of Set 2 | maribo
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | coruripe
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | suez
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | lundazi
# Processing Record 46 of Set 2 | beian
# Processing Record 47 of Set 2 | avera
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | faanui
# Processing Record 2 of Set 3 | caravelas
# Processing Record 3 of Set 3 | stupino
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | victoria
# Processing Record 6 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 3 | port keats
# Processing Record 8 of Set 3 | kununurra
# Processing Record 9 of Set 3 | dingle
# Processing Record 10 of Set 3 | leningradskiy
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | panguna
# Processing Record 13 of Set 3 | heiligenhafen
# Processing Record 14 of Set 3 | matay
# Processing Record 15 of Set 3 | sur
# Processing Record 16 of Set 3 | drochtersen
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | pokhara
# Processing Record 19 of Set 3 | olinda
# Processing Record 20 of Set 3 | bathsheba
# Processing Record 21 of Set 3 | clyde river
# Processing Record 22 of Set 3 | iracoubo
# Processing Record 23 of Set 3 | lata
# Processing Record 24 of Set 3 | nizhniy kuranakh
# Processing Record 25 of Set 3 | chapais
# Processing Record 26 of Set 3 | garissa
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | moree
# Processing Record 29 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 3 | zhangye
# Processing Record 31 of Set 3 | shache
# Processing Record 32 of Set 3 | katsuura
# Processing Record 33 of Set 3 | cape town
# Processing Record 34 of Set 3 | rio grande
# Processing Record 35 of Set 3 | labuhan
# Processing Record 36 of Set 3 | mattru
# Processing Record 37 of Set 3 | arlit
# Processing Record 38 of Set 3 | borama
# City not found. Skipping...
# Processing Record 39 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 3 | kautokeino
# Processing Record 41 of Set 3 | humboldt
# Processing Record 42 of Set 3 | fonte boa
# Processing Record 43 of Set 3 | ahipara
# Processing Record 44 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | tiznit
# Processing Record 47 of Set 3 | xiongshi
# City not found. Skipping...
# Processing Record 48 of Set 3 | baruun-urt
# Processing Record 49 of Set 3 | hambantota
# Processing Record 50 of Set 3 | nicoya
# Processing Record 1 of Set 4 | yulara
# Processing Record 2 of Set 4 | karachev
# Processing Record 3 of Set 4 | gidam
# Processing Record 4 of Set 4 | san ramon
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | moindou
# Processing Record 7 of Set 4 | boa vista
# Processing Record 8 of Set 4 | usak
# Processing Record 9 of Set 4 | muros
# Processing Record 10 of Set 4 | port elizabeth
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | yabrud
# Processing Record 13 of Set 4 | bubaque
# Processing Record 14 of Set 4 | peniche
# Processing Record 15 of Set 4 | catuday
# Processing Record 16 of Set 4 | richards bay
# Processing Record 17 of Set 4 | hobyo
# Processing Record 18 of Set 4 | santa isabel do rio negro
# Processing Record 19 of Set 4 | thompson
# Processing Record 20 of Set 4 | caluquembe
# Processing Record 21 of Set 4 | rocha
# Processing Record 22 of Set 4 | chubbuck
# Processing Record 23 of Set 4 | talawdi
# City not found. Skipping...
# Processing Record 24 of Set 4 | sierra vista
# Processing Record 25 of Set 4 | duz
# City not found. Skipping...
# Processing Record 26 of Set 4 | krasnyy
# Processing Record 27 of Set 4 | hilo
# Processing Record 28 of Set 4 | hithadhoo
# Processing Record 29 of Set 4 | ayna
# Processing Record 30 of Set 4 | parana
# Processing Record 31 of Set 4 | sola
# Processing Record 32 of Set 4 | stolin
# Processing Record 33 of Set 4 | itarema
# Processing Record 34 of Set 4 | carlsbad
# Processing Record 35 of Set 4 | beyneu
# Processing Record 36 of Set 4 | linares
# Processing Record 37 of Set 4 | ngora
# Processing Record 38 of Set 4 | russell
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | fortuna
# Processing Record 41 of Set 4 | gladstone
# Processing Record 42 of Set 4 | karratha
# Processing Record 43 of Set 4 | vardo
# Processing Record 44 of Set 4 | pevek
# Processing Record 45 of Set 4 | lakheri
# Processing Record 46 of Set 4 | saint-georges
# Processing Record 47 of Set 4 | voznesenye
# Processing Record 48 of Set 4 | torbay
# Processing Record 49 of Set 4 | utica
# Processing Record 50 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 1 of Set 5 | iquitos
# Processing Record 2 of Set 5 | fort nelson
# Processing Record 3 of Set 5 | palmer
# Processing Record 4 of Set 5 | hai phong
# City not found. Skipping...
# Processing Record 5 of Set 5 | slave lake
# Processing Record 6 of Set 5 | talnakh
# Processing Record 7 of Set 5 | wajima
# Processing Record 8 of Set 5 | batangafo
# Processing Record 9 of Set 5 | san cristobal
# Processing Record 10 of Set 5 | tuatapere
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | pangnirtung
# Processing Record 13 of Set 5 | scarborough
# Processing Record 14 of Set 5 | virklund
# Processing Record 15 of Set 5 | nhulunbuy
# Processing Record 16 of Set 5 | kailua
# Processing Record 17 of Set 5 | bourail
# Processing Record 18 of Set 5 | hermanus
# Processing Record 19 of Set 5 | saskylakh
# Processing Record 20 of Set 5 | college
# Processing Record 21 of Set 5 | ulaanbaatar
# Processing Record 22 of Set 5 | saint-francois
# Processing Record 23 of Set 5 | baijiantan
# Processing Record 24 of Set 5 | kadaya
# Processing Record 25 of Set 5 | buala
# Processing Record 26 of Set 5 | alofi
# Processing Record 27 of Set 5 | coquimbo
# Processing Record 28 of Set 5 | latung
# Processing Record 29 of Set 5 | lavrentiya
# Processing Record 30 of Set 5 | launceston
# Processing Record 31 of Set 5 | konevo
# Processing Record 32 of Set 5 | mazyr
# Processing Record 33 of Set 5 | purranque
# Processing Record 34 of Set 5 | kolpashevo
# Processing Record 35 of Set 5 | mizan teferi
# Processing Record 36 of Set 5 | provideniya
# Processing Record 37 of Set 5 | bhalki
# Processing Record 38 of Set 5 | longyearbyen
# Processing Record 39 of Set 5 | portland
# Processing Record 40 of Set 5 | stephenville crossing
# Processing Record 41 of Set 5 | flinders
# Processing Record 42 of Set 5 | ust-nera
# Processing Record 43 of Set 5 | puri
# Processing Record 44 of Set 5 | qaanaaq
# Processing Record 45 of Set 5 | vallenar
# Processing Record 46 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 5 | mecca
# Processing Record 48 of Set 5 | guerrero negro
# Processing Record 49 of Set 5 | canutama
# Processing Record 50 of Set 5 | porbandar
# Processing Record 1 of Set 6 | manzanillo
# Processing Record 2 of Set 6 | iqaluit
# Processing Record 3 of Set 6 | egvekinot
# Processing Record 4 of Set 6 | yukamenskoye
# Processing Record 5 of Set 6 | kalmunai
# Processing Record 6 of Set 6 | harer
# Processing Record 7 of Set 6 | tamiahua
# Processing Record 8 of Set 6 | tilichiki
# Processing Record 9 of Set 6 | pontes e lacerda
# Processing Record 10 of Set 6 | ossora
# Processing Record 11 of Set 6 | kruisfontein
# Processing Record 12 of Set 6 | lingyuan
# Processing Record 13 of Set 6 | constitucion
# Processing Record 14 of Set 6 | hwange
# Processing Record 15 of Set 6 | cayenne
# Processing Record 16 of Set 6 | komatipoort
# Processing Record 17 of Set 6 | faya
# Processing Record 18 of Set 6 | meulaboh
# Processing Record 19 of Set 6 | new norfolk
# Processing Record 20 of Set 6 | iwanai
# Processing Record 21 of Set 6 | myitkyina
# Processing Record 22 of Set 6 | northam
# Processing Record 23 of Set 6 | brooks
# Processing Record 24 of Set 6 | san patricio
# Processing Record 25 of Set 6 | gat
# Processing Record 26 of Set 6 | te anau
# Processing Record 27 of Set 6 | zakamensk
# Processing Record 28 of Set 6 | alekseyevka
# Processing Record 29 of Set 6 | omurtag
# Processing Record 30 of Set 6 | skibbereen
# Processing Record 31 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 32 of Set 6 | okhotsk
# Processing Record 33 of Set 6 | mamboma
# Processing Record 34 of Set 6 | lethem
# Processing Record 35 of Set 6 | filadelfia
# Processing Record 36 of Set 6 | half moon bay
# Processing Record 37 of Set 6 | lompoc
# Processing Record 38 of Set 6 | waipawa
# Processing Record 39 of Set 6 | santa cruz
# Processing Record 40 of Set 6 | owosso
# Processing Record 41 of Set 6 | barcelos
# Processing Record 42 of Set 6 | bogovina
# Processing Record 43 of Set 6 | clarksburg
# Processing Record 44 of Set 6 | naze
# Processing Record 45 of Set 6 | taburao
# City not found. Skipping...
# Processing Record 46 of Set 6 | novyy svit
# Processing Record 47 of Set 6 | lieksa
# Processing Record 48 of Set 6 | taoudenni
# Processing Record 49 of Set 6 | golden
# Processing Record 50 of Set 6 | husavik
# Processing Record 1 of Set 7 | carnarvon
# Processing Record 2 of Set 7 | srivardhan
# Processing Record 3 of Set 7 | batagay
# Processing Record 4 of Set 7 | lahij
# Processing Record 5 of Set 7 | santa fe
# Processing Record 6 of Set 7 | miandrivazo
# Processing Record 7 of Set 7 | kodiak
# Processing Record 8 of Set 7 | zhovtneve
# Processing Record 9 of Set 7 | san jose
# Processing Record 10 of Set 7 | la paz
# Processing Record 11 of Set 7 | ponta do sol
# Processing Record 12 of Set 7 | kedrovyy
# Processing Record 13 of Set 7 | guiratinga
# Processing Record 14 of Set 7 | pemangkat
# Processing Record 15 of Set 7 | kirakira
# Processing Record 16 of Set 7 | alta floresta
# Processing Record 17 of Set 7 | haines junction
# Processing Record 18 of Set 7 | krionerion
# City not found. Skipping...
# Processing Record 19 of Set 7 | saint-joseph
# Processing Record 20 of Set 7 | juneau
# Processing Record 21 of Set 7 | hofgeismar
# Processing Record 22 of Set 7 | rawatsar
# Processing Record 23 of Set 7 | goma
# Processing Record 24 of Set 7 | nemuro
# Processing Record 25 of Set 7 | markova
# Processing Record 26 of Set 7 | kamaishi
# Processing Record 27 of Set 7 | danesti
# Processing Record 28 of Set 7 | haapiti
# Processing Record 29 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 30 of Set 7 | dawlatabad
# Processing Record 31 of Set 7 | sitka
# Processing Record 32 of Set 7 | sechura
# Processing Record 33 of Set 7 | hasaki
# Processing Record 34 of Set 7 | hammerfest
# Processing Record 35 of Set 7 | waverly
# Processing Record 36 of Set 7 | maniitsoq
# Processing Record 37 of Set 7 | diamantino
# Processing Record 38 of Set 7 | camacha
# Processing Record 39 of Set 7 | svetlaya
# Processing Record 40 of Set 7 | komsomolskiy
# Processing Record 41 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 7 | jijiga
# Processing Record 43 of Set 7 | buraydah
# Processing Record 44 of Set 7 | bethel
# Processing Record 45 of Set 7 | marzuq
# Processing Record 46 of Set 7 | bandarbeyla
# Processing Record 47 of Set 7 | bengkulu
# Processing Record 48 of Set 7 | farmington
# Processing Record 49 of Set 7 | namibe
# Processing Record 50 of Set 7 | kumluca
# Processing Record 1 of Set 8 | birao
# Processing Record 2 of Set 8 | san jeronimo
# Processing Record 3 of Set 8 | belaya gora
# Processing Record 4 of Set 8 | khilok
# Processing Record 5 of Set 8 | cabedelo
# Processing Record 6 of Set 8 | lorengau
# Processing Record 7 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 8 of Set 8 | nuuk
# Processing Record 9 of Set 8 | ploufragan
# Processing Record 10 of Set 8 | ahuimanu
# Processing Record 11 of Set 8 | mabaruma
# Processing Record 12 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 13 of Set 8 | jieshi
# Processing Record 14 of Set 8 | the valley
# Processing Record 15 of Set 8 | dilla
# Processing Record 16 of Set 8 | vao
# Processing Record 17 of Set 8 | ancud
# Processing Record 18 of Set 8 | ketchikan
# Processing Record 19 of Set 8 | rudbar
# Processing Record 20 of Set 8 | nong kung si
# Processing Record 21 of Set 8 | yeppoon
# Processing Record 22 of Set 8 | iskateley
# Processing Record 23 of Set 8 | culebra
# Processing Record 24 of Set 8 | lagoa
# Processing Record 25 of Set 8 | kimbe
# Processing Record 26 of Set 8 | tezu
# Processing Record 27 of Set 8 | ballina
# Processing Record 28 of Set 8 | kodaikanal
# Processing Record 29 of Set 8 | margate
# Processing Record 30 of Set 8 | rovnoye
# Processing Record 31 of Set 8 | matagami
# Processing Record 32 of Set 8 | eyl
# Processing Record 33 of Set 8 | geraldton
# Processing Record 34 of Set 8 | nanakuli
# Processing Record 35 of Set 8 | xuddur
# Processing Record 36 of Set 8 | krugersdorp
# Processing Record 37 of Set 8 | arica
# Processing Record 38 of Set 8 | nantucket
# Processing Record 39 of Set 8 | laguna
# Processing Record 40 of Set 8 | veere
# Processing Record 41 of Set 8 | lyubeshiv
# City not found. Skipping...
# Processing Record 42 of Set 8 | hami
# Processing Record 43 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 8 | balakhta
# Processing Record 45 of Set 8 | tottori
# Processing Record 46 of Set 8 | cardston
# Processing Record 47 of Set 8 | atikokan
# Processing Record 48 of Set 8 | sao joao da barra
# Processing Record 49 of Set 8 | viedma
# Processing Record 50 of Set 8 | byron bay
# Processing Record 1 of Set 9 | mount gambier
# Processing Record 2 of Set 9 | mandurah
# Processing Record 3 of Set 9 | sabang
# Processing Record 4 of Set 9 | pangody
# Processing Record 5 of Set 9 | pisco
# Processing Record 6 of Set 9 | ikongo
# Processing Record 7 of Set 9 | chara
# Processing Record 8 of Set 9 | dekoa
# City not found. Skipping...
# Processing Record 9 of Set 9 | hovd
# Processing Record 10 of Set 9 | roald
# Processing Record 11 of Set 9 | kendari
# Processing Record 12 of Set 9 | gidole
# Processing Record 13 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 14 of Set 9 | zhuhai
# Processing Record 15 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 9 | mitsamiouli
# Processing Record 17 of Set 9 | kamenka
# Processing Record 18 of Set 9 | bouake
# Processing Record 19 of Set 9 | luwuk
# Processing Record 20 of Set 9 | hokitika
# Processing Record 21 of Set 9 | port hardy
# Processing Record 22 of Set 9 | plouzane
# Processing Record 23 of Set 9 | nowy dwor gdanski
# Processing Record 24 of Set 9 | shu
# Processing Record 25 of Set 9 | mondlo
# Processing Record 26 of Set 9 | bagotville
# Processing Record 27 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 28 of Set 9 | sortland
# Processing Record 29 of Set 9 | klaksvik
# Processing Record 30 of Set 9 | samana
# Processing Record 31 of Set 9 | itoman
# Processing Record 32 of Set 9 | mehamn
# Processing Record 33 of Set 9 | mokrousovo
# Processing Record 34 of Set 9 | temple
# Processing Record 35 of Set 9 | pandan
# Processing Record 36 of Set 9 | araouane
# Processing Record 37 of Set 9 | kieta
# Processing Record 38 of Set 9 | havre-saint-pierre
# Processing Record 39 of Set 9 | brookhaven
# Processing Record 40 of Set 9 | tabas
# Processing Record 41 of Set 9 | ust-kuyga
# Processing Record 42 of Set 9 | sena madureira
# Processing Record 43 of Set 9 | whitianga
# Processing Record 44 of Set 9 | lanas
# Processing Record 45 of Set 9 | saint-denis
# Processing Record 46 of Set 9 | bhatkal
# Processing Record 47 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 9 | poum
# Processing Record 49 of Set 9 | mount isa
# Processing Record 50 of Set 9 | flin flon
# Processing Record 1 of Set 10 | coihaique
# Processing Record 2 of Set 10 | luau
# Processing Record 3 of Set 10 | darhan
# Processing Record 4 of Set 10 | axim
# Processing Record 5 of Set 10 | bloomingdale
# Processing Record 6 of Set 10 | jumla
# Processing Record 7 of Set 10 | vienna
# Processing Record 8 of Set 10 | baghdad
# Processing Record 9 of Set 10 | middelburg
# Processing Record 10 of Set 10 | benghazi
# Processing Record 11 of Set 10 | ilulissat
# Processing Record 12 of Set 10 | mongu
# Processing Record 13 of Set 10 | dhanera
# Processing Record 14 of Set 10 | saint-augustin
# Processing Record 15 of Set 10 | riohacha
# Processing Record 16 of Set 10 | spring hill
# Processing Record 17 of Set 10 | toguchin
# Processing Record 18 of Set 10 | tessalit
# Processing Record 19 of Set 10 | wamba
# Processing Record 20 of Set 10 | whitley bay
# Processing Record 21 of Set 10 | syasstroy
# Processing Record 22 of Set 10 | grand gaube
# Processing Record 23 of Set 10 | derbent
# Processing Record 24 of Set 10 | nambour
# Processing Record 25 of Set 10 | havelock
# Processing Record 26 of Set 10 | lapeer
# Processing Record 27 of Set 10 | gulu
# Processing Record 28 of Set 10 | peachland
# Processing Record 29 of Set 10 | ialibu
# Processing Record 30 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 31 of Set 10 | tadine
# Processing Record 32 of Set 10 | santa maria
# Processing Record 33 of Set 10 | dakar
# Processing Record 34 of Set 10 | ajdabiya
# Processing Record 35 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 10 | staunton
# Processing Record 37 of Set 10 | tomatlan
# Processing Record 38 of Set 10 | huntsville
# Processing Record 39 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 10 | eloy
# Processing Record 41 of Set 10 | urumqi
# Processing Record 42 of Set 10 | hibbing
# Processing Record 43 of Set 10 | lexington
# Processing Record 44 of Set 10 | bassila
# Processing Record 45 of Set 10 | port macquarie
# Processing Record 46 of Set 10 | phan thiet
# Processing Record 47 of Set 10 | vanavara
# Processing Record 48 of Set 10 | kloulklubed
# Processing Record 49 of Set 10 | oda
# Processing Record 50 of Set 10 | san luis
# Processing Record 1 of Set 11 | ati
# Processing Record 2 of Set 11 | antropovo
# Processing Record 3 of Set 11 | broken hill
# Processing Record 4 of Set 11 | korla
# Processing Record 5 of Set 11 | vangaindrano
# Processing Record 6 of Set 11 | mungwi
# Processing Record 7 of Set 11 | riyadh
# Processing Record 8 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 11 | teya
# Processing Record 10 of Set 11 | port lincoln
# Processing Record 11 of Set 11 | shingu
# Processing Record 12 of Set 11 | snezhnogorsk
# Processing Record 13 of Set 11 | tornio
# Processing Record 14 of Set 11 | palu
# Processing Record 15 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 16 of Set 11 | clonakilty
# Processing Record 17 of Set 11 | vanimo
# Processing Record 18 of Set 11 | oktyabrskoye
# Processing Record 19 of Set 11 | villa vazquez
# City not found. Skipping...
# Processing Record 20 of Set 11 | kodinar
# Processing Record 21 of Set 11 | salina cruz
# Processing Record 22 of Set 11 | lewiston
# Processing Record 23 of Set 11 | oistins
# Processing Record 24 of Set 11 | edd
# Processing Record 25 of Set 11 | feicheng
# Processing Record 26 of Set 11 | moose factory
# Processing Record 27 of Set 11 | ugoofaaru
# Processing Record 28 of Set 11 | sendhwa
# Processing Record 29 of Set 11 | gillette
# Processing Record 30 of Set 11 | vibo valentia
# Processing Record 31 of Set 11 | katobu
# Processing Record 32 of Set 11 | pitimbu
# Processing Record 33 of Set 11 | hauterive
# Processing Record 34 of Set 11 | ambilobe
# Processing Record 35 of Set 11 | zapolyarnyy
# Processing Record 36 of Set 11 | kadoma
# Processing Record 37 of Set 11 | gayny
# Processing Record 38 of Set 11 | mandalgovi
# Processing Record 39 of Set 11 | mendi
# Processing Record 40 of Set 11 | novoagansk
# Processing Record 41 of Set 11 | yelizovo
# Processing Record 42 of Set 11 | matara
# Processing Record 43 of Set 11 | batsfjord
# Processing Record 44 of Set 11 | kenora
# Processing Record 45 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 11 | den helder
# Processing Record 47 of Set 11 | nyurba
# Processing Record 48 of Set 11 | stanceni
# Processing Record 49 of Set 11 | cap malheureux
# Processing Record 50 of Set 11 | ecoporanga
# Processing Record 1 of Set 12 | dallas
# Processing Record 2 of Set 12 | minab
# Processing Record 3 of Set 12 | dunedin
# Processing Record 4 of Set 12 | kontagora
# Processing Record 5 of Set 12 | pasni
# Processing Record 6 of Set 12 | takoradi
# Processing Record 7 of Set 12 | okha
# Processing Record 8 of Set 12 | harper
# Processing Record 9 of Set 12 | laredo
# Processing Record 10 of Set 12 | darab
# Processing Record 11 of Set 12 | lafiagi
# Processing Record 12 of Set 12 | pringsewu
# Processing Record 13 of Set 12 | chenzhou
# Processing Record 14 of Set 12 | oranjemund
# Processing Record 15 of Set 12 | monywa
# Processing Record 16 of Set 12 | oreanda
# City not found. Skipping...
# Processing Record 17 of Set 12 | alexandria
# Processing Record 18 of Set 12 | west bay
# Processing Record 19 of Set 12 | passagem franca
# Processing Record 20 of Set 12 | hofn
# Processing Record 21 of Set 12 | bayshore gardens
# Processing Record 22 of Set 12 | kudahuvadhoo
# Processing Record 23 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 24 of Set 12 | hirara
# Processing Record 25 of Set 12 | tura
# Processing Record 26 of Set 12 | moctezuma
# Processing Record 27 of Set 12 | pakokku
# Processing Record 28 of Set 12 | kainantu
# Processing Record 29 of Set 12 | sioux lookout
# Processing Record 30 of Set 12 | hualmay
# Processing Record 31 of Set 12 | bonavista
# Processing Record 32 of Set 12 | padang
# Processing Record 33 of Set 12 | kinston
# Processing Record 34 of Set 12 | kouqian
# Processing Record 35 of Set 12 | lieto
# Processing Record 36 of Set 12 | pinega
# Processing Record 37 of Set 12 | lewistown
# Processing Record 38 of Set 12 | ouegoa
# Processing Record 39 of Set 12 | suchiapa
# Processing Record 40 of Set 12 | kirkland lake
# Processing Record 41 of Set 12 | sekoma
# Processing Record 42 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 43 of Set 12 | totma
# Processing Record 44 of Set 12 | mirabad
# Processing Record 45 of Set 12 | banda aceh
# Processing Record 46 of Set 12 | shimoda
# Processing Record 47 of Set 12 | abastumani
# Processing Record 48 of Set 12 | aklavik
# Processing Record 49 of Set 12 | yorosso
# Processing Record 50 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 13 | nador
# Processing Record 2 of Set 13 | vaitape
# Processing Record 3 of Set 13 | chuy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Butaritari      KI   3.0707  172.7902     82.20        65          86
# 1         Kavieng      PG  -2.5744  150.7967     82.54        67         100
# 2     Saint Cloud      US  45.5608  -94.1625     75.74        78         100
# 3           Bluff      NZ -46.6000  168.3333     44.28        80          84
# 4  Severo-Kurilsk      RU  50.6789  156.1250     48.88        80          12
# 5           Yatou      CN  37.1500  122.3833     65.53        92          20
# 6  Saint-Philippe      RE -21.3585   55.7679     69.39        86          60
# 7            Lebu      CL -37.6167  -73.6500     45.00        91         100
# 8         Mataura      NZ -46.1927  168.8643     38.12        90          27
# 9           Airai      TL  -8.9266  125.4092     57.13        78          98
#
#    Wind Speed Current Description
# 0       16.04     overcast clouds
# 1       13.33     overcast clouds
# 2        9.22     overcast clouds
# 3       10.83       broken clouds
# 4       10.89          few clouds
# 5        5.86          few clouds
# 6       15.03          light rain
# 7       15.05     overcast clouds
# 8        1.92    scattered clouds
# 9        2.77     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
